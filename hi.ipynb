# %% [markdown]
# <a href="https://colab.research.google.com/github/TeslaCybertruck/INSY_Class/blob/main/hi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
world = "Earth"
print(f'Hello {world}')
# Out:
# Hello Earth
